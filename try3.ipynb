# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('nba.csv')
df2 = pd.read_csv('iris.csv')

# %%
df1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
grp = df1.groupby("Team")['Salary']
lst = grp.apply(list)
print(lst)
# Out:
# Team
# Atlanta Hawks             [2000000.0, 1304520.0, 2854940.0, 12000000.0, ...
# Boston Celtics            [7730337.0, 6796117.0, nan, 1148640.0, 5000000...
# Brooklyn Nets             [3425510.0, 845059.0, 1500000.0, 1335480.0, 63...
# Charlotte Hornets         [13125306.0, 947276.0, 189455.0, 947276.0, 525...
# Chicago Bulls             [845059.0, 2250000.0, 16407500.0, 4500000.0, 5...
# Cleveland Cavaliers       [1147276.0, 8193029.0, 16407501.0, 22970500.0,...
# Dallas Mavericks          [1449000.0, 4290000.0, 1100602.0, 3950313.0, 4...
# Denver Nuggets            [2814000.0, 3000000.0, 3533333.0, 10449438.0, ...
# Detroit Pistons           [2500000.0, 6500000.0, 2170465.0, 111444.0, 12...
# Golden State Warriors     [2500000.0, 3873398.0, 13800000.0, 947276.0, 1...
# Houston Rockets           [8193030.0, 306527.0, 6486486.0, 8229375.0, 12...
# Indiana Pacers            [4050000.0, 1007026.0, 10300000.0, 17120106.0,...
# ...

# %%
summary = grp.agg(['mean','median','min','max','std'])
summary
# Out:
#                                 mean     median        min         max  \
# Team
# Atlanta Hawks           4.860197e+06  2854940.0   525093.0  18671659.0
# Boston Celtics          4.181505e+06  3021242.5  1148640.0  12000000.0
# Brooklyn Nets           3.501898e+06  1335480.0   134215.0  19689000.0
# Charlotte Hornets       5.222728e+06  4204200.0   189455.0  13500000.0
# Chicago Bulls           5.785559e+06  2380440.0   525093.0  20093064.0
# Cleveland Cavaliers     7.642049e+06  4975000.0   111196.0  22970500.0
# Dallas Mavericks        4.746582e+06  3950313.0   525093.0  16407500.0
# Denver Nuggets          4.294424e+06  2907000.0   258489.0  14000000.0
# Detroit Pistons         4.477884e+06  2891760.0   111444.0  16000000.0
# Golden State Warriors   5.924600e+06  3815000.0   289755.0  15501000.0
# Houston Rockets         5.018868e+06  2288205.0   200600.0  22359364.0
# Indiana Pacers          4.450122e+06  4000000.0   211744.0  17120106.0
# ...

# %%
df2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
grp= df2.groupby('Species')

# %%
grp.describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
summ = grp.agg(['mean','median', 'max'])
summ
# Out:
#                     Id             SepalLengthCm             SepalWidthCm  \
#                   mean median  max          mean median  max         mean
# Species
# Iris-setosa       25.5   25.5   50         5.006    5.0  5.8        3.418
# Iris-versicolor   75.5   75.5  100         5.936    5.9  7.0        2.770
# Iris-virginica   125.5  125.5  150         6.588    6.5  7.9        2.974
#
#                             PetalLengthCm             PetalWidthCm
#                 median  max          mean median  max         mean median  max
# Species
# Iris-setosa        3.4  4.4         1.464   1.50  1.9        0.244    0.2  0.6
# Iris-versicolor    2.8  3.4         4.260   4.35  5.1        1.326    1.3  1.8
# Iris-virginica     3.0  3.8         5.552   5.55  6.9        2.026    2.0  2.5

# %%
grp.quantile([0.25 , 0.75])
# Out:
#                           Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa     0.25   13.25          4.800         3.125          1.400
#                 0.75   37.75          5.200         3.675          1.575
# Iris-versicolor 0.25   63.25          5.600         2.525          4.000
#                 0.75   87.75          6.300         3.000          4.600
# Iris-virginica  0.25  113.25          6.225         2.800          5.100
#                 0.75  137.75          6.900         3.175          5.875
#
#                       PetalWidthCm
# Species
# Iris-setosa     0.25           0.2
#                 0.75           0.3
# Iris-versicolor 0.25           1.2
#                 0.75           1.5
# Iris-virginica  0.25           1.8
#                 0.75           2.3
