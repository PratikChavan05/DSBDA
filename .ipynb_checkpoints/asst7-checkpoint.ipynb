# %%
pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.9.4)
# Requirement already satisfied: scikit-learn in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.7.2)
# Requirement already satisfied: click in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: numpy>=1.22.0 in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\mrunm\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import pandas as pd
import nltk
import string
import math
# Tokenization, 
# POS Tagging, 
# stop words removal,
# Stemming 
# Lemmatization.

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mrunm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mrunm\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mrunm\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mrunm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mrunm\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
with open("txt1.txt") as file:
    doc1=file.read()

with open("txt2.txt") as file:
    doc2=file.read()

# %%
from nltk.tokenize import word_tokenize , sent_tokenize

# Sentence Level Tokenization
senttok = sent_tokenize(doc1)


#Word level tokenization
wordtok = word_tokenize(doc1)

# %%
for s in senttok[:4]:
    print(s)
    print("---------------------")
# Out:
# Between 2016 and 2019, the state forest department under theÂ BJPÂ government had launched Green Maharashtra drive with an aim to plant 50 crore trees across the state in the four-year period.
# ---------------------
# In October 2019, the government had claimed it had surpassed the target by planting 33 crore trees in July-September 2019.Â The Indian ExpressÂ had found that non-forest agencies â€” such as gram panchayats â€” which were tasked with planting trees had not uploaded the mandatory audio-visual proof of the tree plantation drives on the specially created portal.
# ---------------------
# In Pune Revenue Division, it was claimed the gram panchayats planted 1.7 crore saplings; however, no evidence was uploaded for 87 per cent (1.49 crore) saplings.
# ---------------------
# Also, out of the 59 government agencies involved in the drive as many as 38 had not submitted survival reports about the saplings.
# ---------------------

# %%
wordtok[:5]
# Out:
# ['Between', '2016', 'and', '2019', ',']

# %%
# from nltk.corpus import stopwords

##################################################################################

# 🔍 What is stopwords?

# A predefined list of common useless words

# Examples:
# the, is, in, and, are, of, to, a

##################################################################################


stop_words = set(stopwords.words('english'))
list(stop_words)[:10]
# Out:
# ['haven',
#  'did',
#  "she's",
#  'ain',
#  'its',
#  "mightn't",
#  'their',
#  "we'll",
#  'aren',
#  "we've"]

# %%
wordtok = [token for token in wordtok if token not in stop_words]
wordtok[:5]
# Out:
# ['Between', '2016', '2019', ',', 'state']

# %%
# 🔷 2. POS TAGGING
# 👉 Definition:

# Assign grammatical role to each word.
# nouns ('NN')
# verb ('VBZ')
# adjectives ('JJ')
# determiners ('DT')

pos_tags = nltk.pos_tag(wordtok)
pos_tags[:10]
# Out:
# [('Between', 'IN'),
#  ('2016', 'CD'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('state', 'NN'),
#  ('forest', 'JJS'),
#  ('department', 'NN'),
#  ('theÂ', 'NN'),
#  ('BJPÂ', 'NNP'),
#  ('government', 'NN')]

# %%
# 🔷 4. STEMMING
# 👉 Definition:

# Cut words to root form (may not be correct English)

# Example:
# playing → play
# studies → studi
# running → run

# 🔍 Types of Stemmers:
# Porter (most common)
# Lancaster (aggressive)
# Snowball


from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmedwords=[]
for word in wordtok:
    stemmedwords.append(stemmer.stem(word))

dict(zip(wordtok[:10],stemmedwords[:10]))
# Out:
# {'Between': 'between',
#  '2016': '2016',
#  '2019': '2019',
#  ',': ',',
#  'state': 'state',
#  'forest': 'forest',
#  'department': 'depart',
#  'theÂ': 'theâ',
#  'BJPÂ': 'bjpâ',
#  'government': 'govern'}

# %%
# 🔷 5. LEMMATIZATION
# 👉 Definition:

# Convert word → dictionary base form

# Example:
# running → run
# better → good

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemwords=[]
for word in wordtok:
    #lemwords.append(lemmatizer.lemmatize(word))

    # ⚠ Important:
    # Better results if POS given:
     lemwords.append(lemmatizer.lemmatize(word, pos='v'))

dict(zip(wordtok[:50],lemwords[:50]))
# Out:
# {'Between': 'Between',
#  '2016': '2016',
#  '2019': '2019',
#  ',': ',',
#  'state': 'state',
#  'forest': 'forest',
#  'department': 'department',
#  'theÂ': 'theÂ',
#  'BJPÂ': 'BJPÂ',
#  'government': 'government',
#  'launched': 'launch',
#  'Green': 'Green',
#  'Maharashtra': 'Maharashtra',
#  'drive': 'drive',
#  'aim': 'aim',
#  'plant': 'plant',
#  '50': '50',
#  'crore': 'crore',
#  'trees': 'tree',
#  'across': 'across',
#  'four-year': 'four-year',
#  'period': 'period',
#  '.': '.',
#  'In': 'In',
#  'October': 'October',
#  'claimed': 'claim',
#  'surpassed': 'surpass',
#  'target': 'target',
#  'planting': 'plant',
#  '33': '33',
#  'July-September': 'July-September',
#  '2019.Â': '2019.Â',
#  'The': 'The',
#  'Indian': 'Indian',
#  'ExpressÂ': 'ExpressÂ',
#  'found': 'find',
#  'non-forest': 'non-forest',
#  'agencies': 'agencies',
#  'â€': 'â€',
#  '”': '”',
#  'gram': 'gram',
#  'panchayats': 'panchayats'}

# %%
# 🔷 6. TERM FREQUENCY (TF)
# 👉 Definition:

# How often word appears in document

# Formula:
# TF = count(word) / total words

#----------------------------------------------------------------------------------------------

##### USING LIBRARY ----- Calculating frequency 

from nltk.probability import FreqDist
fdist = FreqDist(wordtok)
fdist

# total number of words
total_words = len(wordtok)

# calculate TF
tf = {}

for word, count in fdist.items():
    tf[word] = count / total_words
# example
print(tf)

#----------------------------------------------------------------------------------------------

##### USING Counter  ----- Calculating frequency 

from collections import Counter
fdist1 = Counter(wordtok)

620469083, 'may': 0.0021321961620469083, 'meet': 0.0021321961620469083, 'due': 0.0021321961620469083, 'unavailability': 0.0021321961620469083, 'funds': 0.0021321961620469083, 'Last': 0.0021321961620469083, '70': 0.0021321961620469083, 'six': 0.0021321961620469083, 'talukas': 0.0021321961620469083, 'namely': 0.0021321961620469083, 'Maval': 0.0021321961620469083, 'Mulshi': 0.0021321961620469083, 'Daund': 0.0021321961620469083, 'Indapur': 0.0021321961620469083, 'Baramati': 0.0021321961620469083, 'Havveli': 0.0021321961620469083, 'preparations': 0.0021321961620469083, 'done': 0.0021321961620469083, '4': 0.008528784648187633, 'special': 0.0021321961620469083, 'emphasis': 0.0021321961620469083, 'teakwood': 0.0021321961620469083, 'National': 0.0042643923240938165, 'Forest': 0.014925373134328358, 'Policy': 0.0021321961620469083, 'aims': 0.0042643923240938165, 'emphasizes': 0.0021321961620469083, 'maintaining': 0.00213219 ...

# %% [raw]
# 🔷 7. INVERSE DOCUMENT FREQUENCY (IDF)
# 👉 Definition:
#
# Measures rarity of word
#
# Formula:
# IDF = log(N / df)
#
# Symbol	Meaning
# N	total documents
# df	docs containing word
#
# 🔷 8. TF-IDF
# 👉 Definition:
# TF-IDF = TF × IDF

# %%
# USING FORMULA

d1tok = word_tokenize(doc1)
d2tok = word_tokenize(doc2)

d1df = Counter(d1tok)
d2df = Counter(d2tok)

allwords = set(d1tok) | set(d2tok)

n=2

idf={}

for word in allwords :
    df = (1 if word in d1df else 0) + (1 if word in d2df else 0)
    idf[word]=math.log(n/(df))

d1tfidfscores = []
for token in d1tok:
    d1tfidfscores.append([token,d1df[token]*idf[token]])

d2tfidfscores = []
for token in d2tok:
    d2tfidfscores.append([token,d2df[token]*idf[token]])
    

d1tfidfscores[:30]
# Out:
# [['Between', 0.6931471805599453],
#  ['2016', 2.0794415416798357],
#  ['and', 0.0],
#  ['2019', 0.0],
#  [',', 0.0],
#  ['the', 0.0],
#  ['state', 0.0],
#  ['forest', 0.0],
#  ['department', 1.3862943611198906],
#  ['under', 0.0],
#  ['theÂ', 0.6931471805599453],
#  ['BJPÂ', 0.6931471805599453],
#  ['government', 0.0],
#  ['had', 4.852030263919617],
#  ['launched', 0.6931471805599453],
#  ['Green', 2.0794415416798357],
#  ['Maharashtra', 3.4657359027997265],
#  ['drive', 0.0],
#  ['with', 4.852030263919617],
#  ['an', 0.0],
#  ['aim', 1.3862943611198906],
#  ['to', 0.0],
#  ['plant', 2.0794415416798357],
#  ['50', 2.0794415416798357],
#  ['crore', 8.317766166719343],
#  ['trees', 0.0],
#  ['across', 0.0],
#  ['the', 0.0],
#  ['state', 0.0],
#  ['in', 0.0]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Step 2: Create vectorizer
vectorizer = TfidfVectorizer()

# Step 3: Fit and transform
tfidf_matrix = vectorizer.fit_transform([doc1,doc2])

# Step 4: Get words (features)
feature_names = vectorizer.get_feature_names_out()

# Step 5: Convert to array (for display)
print("Words:", feature_names)
print("TF-IDF Matrix:\n", tfidf_matrix.toarray())
# Out:
# Words: ['05' '127' '13' '15' '17' '1926â' '1st' '1stâ' '2016' '2017' '2017â'
#  '2018' '2019' '2030' '24' '250' '33' '38' '49' '50' '59' '60' '70' '79'
#  '7th' '7thâ' '80' '82' '87' '89' '95' 'about' 'accomplished' 'according'
#  'across' 'activists' 'activities' 'adding' 'affecting' 'agencies' 'aim'
#  'aims' 'all' 'allocated' 'along' 'also' 'an' 'and' 'announced' 'annual'
#  'another' 'application' 'are' 'area' 'army' 'around' 'as' 'ascertain'
#  'at' 'audio' 'average' 'awareness' 'aâ' 'baramati' 'be' 'been' 'being'
#  'besides' 'between' 'betweenâ' 'bid' 'billion' 'bjpâ' 'body' 'by'
#  'called' 'campaign' 'can' 'carbon' 'carried' 'carry' 'celebrateâ' 'cent'
#  'change' 'chauhan' 'circle' 'citing' 'claimed' 'climate' 'codes'
#  'collective' 'colleges' 'combat' 'committed' 'comparatively' 'compared'
#  'comprises' 'computer' 'concern' 'consecutive' 'consistency' 'consonance'
#  'country' 'countrys' 'cover' 'created' 'crore' 'croreâ' 'csr' 'dara'
#  'daund' 'day' 'dedicated' 'defence' 'department' 'departments' 'details'
#  'development' 'disease' 'district' 'division' 'divisions' 'done'
#  'download' 'drive' 'drives' 'driveâ' 'due' 'during' 'emissions'
#  'emphasis' 'emphasizes' 'ensure' 'especially' 'evidence' 'exactly'
#  'example' 'express' 'expressâ' 'extent' 'farms' 'few' 'figure' 'final'
#  'first' 'five' 'for' 'forest' 'forests' 'formed' 'found' 'four' 'freeâ'
#  'from' 'funds' 'further' 'geo' 'geographical' 'gov' 'government' 'gram'
#  'green' 'greenarmy' 'growing' 'had' 'happened' 'harit' 'has' 'have'
#  'havveli' 'he' 'hectares' 'hello' 'helpline' 'highways' 'hourâ' 'how'
#  'however' 'in' 'increase' 'increased' 'increasing' 'indapur' 'india'
#  'indian' 'individual' 'individuals' 'industrial' 'information'
#  'initiated' 'integrated' 'interested' 'into' 'involved' 'involvement'
#  'inâ' 'is' 'it' 'its' 'july' 'kilometers' 'kind' 'lack' 'lakh' 'land'
#  'last' 'launched' 'lawmakers' 'led' 'level' 'location' 'long'
#  'mahaforest' 'maharashtra' 'maintain' 'maintaining' 'mandatory' 'manoj'
#  'many' 'mass' 'maval' 'may' 'meet' 'miles' 'million' 'millions'
#  'minister' 'mission' 'mobile' 'modest' 'momentum' 'monitor' 'more' 'most'
#  'mulshi' 'my' 'nabard' 'namely' 'national' 'ncc' 'newspaper' 'next'
#  'ngos' 'no' 'non' 'not' 'nss' 'number' 'numbers' 'october' 'of'
#  'official' 'officials' 'ofâ' 'on' 'only' 'operational' 'or'
#  'organisations' 'organizational' 'other' 'out' 'over' 'panchayats' 'part'
#  'participate' 'participation' 'people' 'per' 'period' 'pioneer' 'place'
#  'planned' 'plant' 'plantation' 'planted' 'plantedâ' 'planting'
#  'plantingâ' 'plants' 'plantsâ' 'platform' 'policy' 'population'
#  'populous' 'portal' 'pradesh' 'preparations' 'programme' 'progress'
#  'project' 'proof' 'protection' 'provide' 'public' 'pune' 'put' 'qr'
#  'quoted' 'railways' 'rapidly' 'record' 'reduce' 'regarding' 'regions'
#  'register' 'related' 'remains' 'report' 'reported' 'reports' 'resounding'
#  'rest' 'revenue' 'riverbanks' 'said' 'saplings' 'saying' 'schools'
#  'seamless' 'sectors' 'sena' 'september' 'set' 'shall' 'should' 'singh'
#  'single' 'six' 'so' 'society' 'solapur' 'special' 'specially' 'species'
#  'spokesperson' 'sqare' 'stakeholders' 'state' 'stress' 'students'
#  'submitted' 'success' 'successful' 'succumb' 'such' 'sunday' 'surpassed'
#  'survey' 'survival' 'survive' 'survived' 'system' 'tagged' 'talukas'
#  'target' 'targets' 'tasked' 'teakwood' 'teams' 'term' 'than' 'that'
#  'thatâ' 'the' 'their' 'there' 'these' 'theâ' 'third' 'this' 'three'
#  'through' 'to' 'told' 'toll' 'took' 'total' 'tree' 'trees'
#  'unavailability' 'under' 'up' 'uploaded' 'use' 'usually' 'uttar'
#  'vanmohotsav' 'verify' 'view' 'visual' 'viz' 'volunteering' 'volunteers'
#  'vowed' 'was' 'water' 'we' 'websiteâ' 'were' 'what' 'where' 'whether'
#  'which' 'wide' 'wildlife' 'will' 'with' 'within' 'without' 'work' 'www'
#  'year' 'years']
# TF-IDF Matrix:
#  [[0.         0.         0.01875455 0.         0.01875455 0.01875455
#   0.0375091  0.0375091  0.05626365 0.02668803 0.01875455 0.01875455
#   0.05337607 0.         0.01875455 0.         0.0750182  0.01875455
#   0.01875455 0.05626365 0.01875455 0.         0.01875455 0.
#   0.01875455 0.0375091  0.         0.01875455 0.01875455 0.
#   0.         0.02668803 0.01875455 0.         0.01334402 0.
#   0.01875455 0.         0.01875455 0.0375091  0.0375091  0.0375091
#   0.04003205 0.         0.01334402 0.01334402 0.02668803 0.24019231
#   0.01875455 0.         0.         0.05626365 0.         0.01334402
#   0.0375091  0.01875455 0.06672009 0.         0.0375091  0.01875455
#   0.         0.01875455 0.0375091  0.01875455 0.05626365 0.02668803
#   0.         0.         0.01875455 0.01875455 0.         0.
#   0.01875455 0.01875455 0.02668803 0.0375091  0.         0.01334402
#   0.         0.         0.         0.01875455 0.01875455 0.
#   0.         0.0375091  0.         0.0375091  0.         0.
#   0.01875455 0.01875455 0.         0.         0.01875455 0.
#   0.0375091  0.01875455 0.         0.01875455 0.01875455 0.01875455
#   0.         0.01875455 0.01334402 0.0375091  0.22505461 0.01875455
#   0.01875455 0.         0.01875455 0.01334402 0.01875455 0.01875455
#   0.13128185 0.01875455 0.01875455 0.         0.         0.01875455
#   0.0375091  0.01875455 0.01875455 0.01875455 0.04003205 0.01334402
#   0.01875455 0.01875455 0.01875455 0.         0.01875455 0.01875455
#   0.01875455 0.01875455 0.01875455 0.         0.01875455 0.
#   0.01875455 0.         0.         0.         0.01875455 0.01875455
#   0.01875455 0.         0.06672009 0.18681624 0.         0.
#   0.01875455 0.01334402 0.01875455 0.0375091  0.01875455 0.
#   0.         0.01875455 0.01875455 0.05337607 0.0375091  0.0750182
#   0.01875455 0.         0.13128185 0.         0.01875455 0.06672009
#   0.         0.01875455 0.         0.         0.01875455 0.01875455
#   0.01334402 0.01875455 0.         0.02668803 0.24019231 0.
#   0.         0.         0.01875455 0.         0.01334402 0.01875455
#   0.01875455 0.         0.01875455 0.01875455 0.01875455 0.01875455
